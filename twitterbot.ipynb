# %%
import tweepy
import time

# %%
CONSUMER_KEY="tkBz3ewGYoHivWKkyYcRfqk9z"
CONSUMER_SECRET="Dkwju8fPTU3LA0qt8zjCadmCPLL43DEpsQW1TglBFXlgVIS3GH"
ACCESS_KEY="902905259231633408-1ETuKEku0dWcktANdTe7okfPzqP3Y3T"
ACCESS_SECRET="PVh7E3w3lF5jU7AU08OIAr2d69zjzRsBKcNb2LzBoNRZR"

# %%
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_KEY, ACCESS_SECRET)
api = tweepy.API(auth)

# %%
api

# %%
api.mentions_timeline()
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-14-5e24c2713ffe> in <module>
# ----> 1 api.mentions_timeline()
#
# c:\users\krishnakakade\appdata\local\programs\python\python37-32\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# c:\users\krishnakakade\appdata\local\programs\python\python37-32\lib\site-packages\tweepy\binder.py in execute(self)
#     229
#     230                 if is_rate_limit_error_message(error_msg):
# --> 231                     raise RateLimitError(error_msg, resp)
#     232                 else:
#     233                     raise TweepError(error_msg, resp, api_code=api_error_code)
#
# ...

# %%
mentions=api.mentions_timeline()
api = tweepy.api(auth, wait_on_rate_limit=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-cdaeae4b91fa> in <module>
#       1 mentions=api.mentions_timeline()
# ----> 2 api = tweepy.api(auth, wait_on_rate_limit=True)
#
# TypeError: 'API' object is not callable

# %%
mentions
# Out:
# [Status(_api=<tweepy.api.API object at 0x01578DB0>, _json={'created_at': 'Wed Oct 02 18:07:15 +0000 2019', 'id': 1179457834150330368, 'id_str': '1179457834150330368', 'text': 'twitterbot tweet #twitterbot my bot is coming soon #TwitchCon @krishna_9918', 'truncated': False, 'entities': {'hashtags': [{'text': 'twitterbot', 'indices': [17, 28]}, {'text': 'TwitchCon', 'indices': [51, 61]}], 'symbols': [], 'user_mentions': [{'screen_name': 'krishna_9918', 'name': 'krishna kakade', 'id': 902905259231633408, 'id_str': '902905259231633408', 'indices': [62, 75]}], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 902905259231633408, 'id_str': '902905259231633408', 'name': 'krishna kakade', 'screen_name': 'krishna_9918', 'location': 'localhost ', 'description': 'Think Like 
# ...

# %%
type(mentions)
# Out:
# tweepy.models.ResultSet

# %%
#listdata is comming overhere
type(mentions[0])
# Out:
# tweepy.models.Status

# %%
mentions[0].__dict__
# Out:
# {'_api': <tweepy.api.API at 0x1578db0>,
#  '_json': {'created_at': 'Wed Oct 02 18:07:15 +0000 2019',
#   'id': 1179457834150330368,
#   'id_str': '1179457834150330368',
#   'text': 'twitterbot tweet #twitterbot my bot is coming soon #TwitchCon @krishna_9918',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'twitterbot', 'indices': [17, 28]},
#     {'text': 'TwitchCon', 'indices': [51, 61]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'krishna_9918',
#      'name': 'krishna kakade',
#      'id': 902905259231633408,
#      'id_str': '902905259231633408',
#      'indices': [62, 75]}],
#    'urls': []},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 902905259231633408,
#    'id_str': '902905259231633408',
# ...

# %%
mentions[0].__dict__.keys()
# Out:
# dict_keys(['_api', '_json', 'created_at', 'id', 'id_str', 'text', 'truncated', 'entities', 'source', 'source_url', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'author', 'user', 'geo', 'coordinates', 'place', 'contributors', 'is_quote_status', 'retweet_count', 'favorite_count', 'favorited', 'retweeted', 'lang'])

# %%
mentions[0].text
# Out:
# '@krishna_9918 thanks bro'

# %%
mentions=api.mentions_timeline()
for mention in mentions:
    print (str(mention.id)+'-'+mention.text)
    if '#twitterbot' in mention.text.lower():
        print('found #twitterbot')
        print('responding back.....')
# Out:
# 1179552116282576896-#twitterbot my bot @krishna_9918
# found #twitterbot
# responding back.....
# 1179545351704834048-@krishna_9918#HelloWorld back to you!
# 1178871823955480578-@krishna_9918 thanks bro
# 1177226773131608064-@krishna_9918 @ham_gretsky Lol
# 1162009072511737856-@krishna_9918 @t_tarczynski @tobimori @jetbrains Yes I do need those stickers  !!!
# 1161416784265637889-@krishna_9918 I’m in the responsive web section. Just one more to finish and I’m stuck in the advanced JavaScript section too 😅
# 1156927235225522176-@krishna_9918 We are in the process of revamping our merchandise shop which will carry these. In the meantime, if y… https://t.co/0YX19YKFB7
# 1078901735869972480-@RavenderSingh16 @AmitShah @cmohry @ndtv @abpnewstv @RahulGandhi @rajnathsingh @SatlokChannel @IndiaToday… https://t.co/JueHWfZ7Gm
# 1038955447288455168-#MondayMotivation
# हजरत मोहम्मद जी ने कभी जीव हिंसा नहीं की थी ।उन्होंने बस लोगों के कहने पर गाय को (वचन से )मारकर… https://t.co/xpTw5IgqzS
# ...

# %%
r1=mentions[0]

# %%
r1.text
# Out:
# '@krishna_9918 thanks bro'

# %%
FILE_NAME = 'last_seen_id.txt'

def retrieve_last_seen_id(file_name):
    f_read = open(file_name, 'r')
    last_seen_id = int(f_read.read().strip())
    f_read.close()
    return last_seen_id

def store_last_seen_id(last_seen_id, file_name):
    f_write = open(file_name, 'w')
    f_write.write(str(last_seen_id))
    f_write.close()
    return

def reply_to_tweets():
    print('retrieving and replying to tweets...', flush=True)
    # DEV NOTE: use 1060651988453654528 for testing.
    last_seen_id = retrieve_last_seen_id(FILE_NAME)
    # NOTE: We need to use tweet_mode='extended' below to show
    # all full tweets (with full_text). Without it, long tweets
    # would be cut off.
    mentions = api.mentions_timeline(
                        last_seen_id,
                        tweet_mode='extended')
    for mention in reversed(mentions):
        print(str(mention.id) + ' - ' + mention.full_text, flush=True)
        last_seen_id = mention.id
        store_last_seen_id(last_seen_id, FILE_NAME)
        if '#twitterbot' in mention.full_text.lower():
            print('found #twitterbot!', flush=True)
            print('responding back...', flush=True)
            api.update_status('@' + mention.user.screen_name +
                    '#twitterbot back to you!', mention.id)

while True:
    reply_to_tweets()
    time.sleep(1)
# Out:
# retrieving and replying to tweets...
# 1179552116282576896 - #twitterbot my bot @krishna_9918
# found #twitterbot!
# responding back...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# retrieving and replying to tweets...
# ...
